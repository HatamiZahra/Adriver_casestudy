# %% [markdown]
# Adriver Case Study
#
# Using your knowledge, the two datasets provided and your research, try to answer the following case.
# You work in the Data Division of Adriver. The Marketing team needs to know if the VTC advertising campaign sponsored by SILVER Dream, a famous brand of senior accessories, worked well.
# This was a test ad campaign with only 10 VTCs over two weeks.
# The brand wanted to reach the +65 years old, its target customer.
# You have :
# - The tracking data of the VTCs on which the ad in question was displayed, anonymized. (vtc_tracking.csv)
# - GPS position data from smartphones, also completely anonymized. (uuid_tracking.csv)
# - Open Data from INSEE on Parisian demography (see link on Iris).
# The goal, using this data, is to come up with an estimate of the campaign's KPIs. The marketing team asks you for the following figures:
# - The size of the target audience in the study area.
# - The number of Opportunities To See (OTV) generated by the campaign
# - The average repetition of the campaign
# - The audience of the campaign
# - The advertising coverage
# Feel free to take a look at this site, to understand the above terms.
# You need to give the most accurate estimate of these KPIs, as well as a quick explanation of the methodology used. This will allow the sales team to give a coherent speech in front of their client and to justify the figures of the campaign.
# At the next meeting, present your results in the form of a short PPT, a Word document or with your code, as you see fit.
# Good luck!

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load Datasets

# %%
uuid = pd.read_csv("uuid_tracking.csv", sep = ";")
vehicleid = pd.read_csv("vehicle_tracking.csv")
insee = pd.read_csv("base-ic-evol-struct-pop-2017.CSV", sep = ";")
inseemeta = pd.read_csv("meta_base-ic-evol-struct-pop-2017.CSV", sep = ";")
com = pd.read_csv("commune2021.csv")
# Out:
# C:\Users\zhrht\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (0,1,4) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
uuid
# Out:
#       pseudo_id  consentMedia  consentData         date_uuid      speed  \
# 0         0eb25          True         True  14/09/2021 13:58   0.000000
# 1         C3473          True         True  09/09/2021 18:27   0.000000
# 2         49cef          True         True  14/09/2021 12:50  13.046592
# 3         93e8c          True        False  14/09/2021 18:21  10.886680
# 4         56D83          True         True  11/09/2021 16:05   3.578376
# ...         ...           ...          ...               ...        ...
# 80645     73009          True         True  08/09/2021 12:39   0.000000
# 80646     73009          True         True  08/09/2021 11:52   0.000000
# 80647     73009          True         True  08/09/2021 13:14   0.000000
# 80648     73009          True         True  08/09/2021 11:44   0.000000
# 80649     73009          True         True  08/09/2021 11:46   7.284147
#
#        accuracy    altitude  verticalAccuracy   os          deviceModel  \
# 0            15  169.000000          0.000000  and      Xiaomi MI MAX 2
# 1            10   30.974026          4.000000  ios            iPhone8,1
# 2            21  103.000000          3.000000  and  motorola Moto G (5)
# 3             2   71.000000        108.000000  and     samsung SM-A530F
# 4            10   59.289700          4.000000  ios            iPhone7,2
# ...         ...         ...               ...  ...                  ...
# 80645      2000   50.126553         60.827324  ios           iPhone10,4
# 80646      2000   50.126553         60.827324  ios           iPhone10,4
# 80647      2000   50.126553         60.827324  ios           iPhone10,4
# 80648      2000   50.126553         60.827324  ios           iPhone10,4
# 80649      2000   50.126553         60.827324  ios           iPhone10,4
#
#                                        location
# 0      POINT(2.31323444843292 48.8488971590996)
# 1      POINT(2.31348294019699 48.8712033033371)
# 2      POINT(2.31104499101639 48.8806031346321)
# 3      POINT(2.31671500205994 48.8471108078957)
# 4      POINT(2.32746052742004 48.8833501338959)
# ...                                         ...
# 80645   POINT(2.32523882389069 48.858107984066)
# 80646  POINT(2.32524847984314 48.8581141829491)
# 80647    POINT(2.325235247612 48.8581080436707)
# 80648  POINT(2.32524710893631 48.8581057190895)
# 80649  POINT(2.32522505521774 48.8580371141434)
#
# [80650 rows x 11 columns]

# %%
uuid.columns
# Out:
# Index(['pseudo_id', 'consentMedia', 'consentData', 'date_uuid', 'speed',
#        'accuracy', 'altitude', 'verticalAccuracy', 'os', 'deviceModel',
#        'location'],
#       dtype='object')

# %%
uuid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80650 entries, 0 to 80649
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   pseudo_id         80650 non-null  object
#  1   consentMedia      80650 non-null  bool
#  2   consentData       80650 non-null  bool
#  3   date_uuid         80650 non-null  object
#  4   speed             80648 non-null  float64
#  5   accuracy          80650 non-null  int64
#  6   altitude          78889 non-null  float64
#  7   verticalAccuracy  78889 non-null  float64
#  8   os                80650 non-null  object
#  9   deviceModel       80650 non-null  object
#  10  location          80650 non-null  object
# dtypes: bool(2), float64(3), int64(1), object(5)
# memory usage: 5.7+ MB

# %%
vehicleid.tail()
# Out:
#        vehicle_id                               trip_id             date_vtc  \
# 41995       59518  ff461cde-9f0e-49a4-9cbe-f53f6e5fa60b  2021-09-03 21:08:49
# 41996       59518  ff461cde-9f0e-49a4-9cbe-f53f6e5fa60b  2021-09-04 00:06:17
# 41997       59518  ff461cde-9f0e-49a4-9cbe-f53f6e5fa60b  2021-09-04 00:52:34
# 41998       59518  ff461cde-9f0e-49a4-9cbe-f53f6e5fa60b  2021-09-04 01:01:30
# 41999       59518  ff461cde-9f0e-49a4-9cbe-f53f6e5fa60b  2021-09-04 01:40:07
#
#                                 location
# 41995   POINT(2.3235375123 48.869646472)
# 41996  POINT(2.3218290086 48.8660899855)
# 41997  POINT(2.31495174035 48.855575531)
# 41998  POINT(2.3225859406 48.8734018485)
# 41999   POINT(2.3468510191 48.883030823)

# %%
vehicleid['date_vtc'] =  pd.to_datetime(vehicleid['date_vtc'])

# %%
vehicleid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42000 entries, 0 to 41999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   vehicle_id  42000 non-null  int64
#  1   trip_id     42000 non-null  object
#  2   date_vtc    42000 non-null  datetime64[ns]
#  3   location    42000 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 1.3+ MB

# %%
vehicleid.sort_values(by='date_vtc', ascending=False)
# Out:
#        vehicle_id                               trip_id            date_vtc  \
# 137           654  e2dc400a-f494-4f9b-9a42-acbd4fe7630e 2021-09-14 23:59:44
# 6439        81795  f8791a9c-730a-437b-9f60-0272d3974a06 2021-09-14 23:59:43
# 3817          654  e2dc400a-f494-4f9b-9a42-acbd4fe7630e 2021-09-14 23:59:40
# 12243       81795  f8791a9c-730a-437b-9f60-0272d3974a06 2021-09-14 23:59:38
# 17906       81795  f8791a9c-730a-437b-9f60-0272d3974a06 2021-09-14 23:59:35
# ...           ...                                   ...                 ...
# 18245       89665  7c890f77-6002-4925-9ca4-1905dd70954d 2021-09-01 00:01:52
# 995         89665  7c890f77-6002-4925-9ca4-1905dd70954d 2021-09-01 00:01:14
# 6774        89665  7c890f77-6002-4925-9ca4-1905dd70954d 2021-09-01 00:00:57
# 18254       89665  7c890f77-6002-4925-9ca4-1905dd70954d 2021-09-01 00:00:28
# 16295       89665  7c890f77-6002-4925-9ca4-1905dd70954d 2021-09-01 00:00:21
#
#                                        location
# 137            POINT(2.3169846435 48.875122968)
# 6439          POINT(2.34094694915 48.875151416)
# 3817            POINT(2.316725124 48.875151416)
# 12243  POINT(2.34015397276667 48.8748859026667)
# 17906          POINT(2.3395628449 48.874724698)
# ...                                         ...
# 18245          POINT(2.3020406424 48.864340101)
# 995                POINT(2.3014999767 48.86471)
# 6774         POINT(2.30171624295 48.8647526805)
# 18254          POINT(2.3019325093 48.864766908)
# 16295         POINT(2.30206226905 48.864823815)
#
# [42000 rows x 4 columns]

# %%
uuid['date_uuid'] =  pd.to_datetime(uuid['date_uuid'])
uuid.sort_values(by='date_uuid', ascending=False)
# Out:
#       pseudo_id  consentMedia  consentData           date_uuid       speed  \
# 7524      1A941          True         True 2021-12-09 23:59:00  167.579052
# 65586     8601b          True         True 2021-12-09 23:49:00    0.000000
# 14200         0          True         True 2021-12-09 23:49:00   18.571991
# 35349     60303          True         True 2021-12-09 23:48:00    0.000000
# 32779     4a158          True         True 2021-12-09 23:48:00    4.434877
# ...         ...           ...          ...                 ...         ...
# 61077     0d08a          True         True 2021-01-09 01:55:00    0.000000
# 74383     4d229          True         True 2021-01-09 01:54:00    0.000000
# 33863     4d229          True         True 2021-01-09 01:39:00    0.000000
# 25760     3981E          True         True 2021-01-09 00:08:00   15.666392
# 6043      3981E          True         True 2021-01-09 00:03:00   20.746327
#
#        accuracy    altitude  verticalAccuracy   os       deviceModel  \
# 7524         65   33.435486         29.832605  ios          iPad11,1
# 65586        13   81.000000          3.000000  and  samsung SM-A415F
# 14200       165   37.529587         38.074486  ios        iPhone10,4
# 35349         4         NaN               NaN  ios        iPhone10,5
# 32779        15  100.000000          3.000000  and  samsung SM-G965F
# ...         ...         ...               ...  ...               ...
# 61077        23   92.000000          5.000000  and  samsung SM-G998B
# 74383        18   79.000000          3.000000  and  samsung SM-A515F
# 33863        12         NaN               NaN  and  samsung SM-A515F
# 25760       165   49.272331         29.291504  ios        iPhone11,2
# 6043         65   35.263290         66.178322  ios        iPhone11,2
#
#                                        location
# 7524   POINT(2.32003057003021 48.8623678088188)
# 65586  POINT(2.31854194402695 48.8574475049973)
# 14200  POINT(2.31442844867706 48.8600109815598)
# 35349  POINT(2.32138758897781 48.8803889751434)
# 32779  POINT(2.33505201339722 48.8805416226387)
# ...                                         ...
# 61077  POINT(2.32336157560348 48.8800246119499)
# 74383  POINT(2.34487599134445 48.8740048408508)
# 33863  POINT(2.34320288896561 48.8722257018089)
# 25760  POINT(2.30103427171707 48.8716050982475)
# 6043   POINT(2.31355160474777 48.8627104759216)
#
# [80650 rows x 11 columns]

# %%
uuid
# Out:
#       pseudo_id  consentMedia  consentData           date_uuid      speed  \
# 0         0eb25          True         True 2021-09-14 13:58:00   0.000000
# 1         C3473          True         True 2021-09-09 18:27:00   0.000000
# 2         49cef          True         True 2021-09-14 12:50:00  13.046592
# 3         93e8c          True        False 2021-09-14 18:21:00  10.886680
# 4         56D83          True         True 2021-11-09 16:05:00   3.578376
# ...         ...           ...          ...                 ...        ...
# 80645     73009          True         True 2021-08-09 12:39:00   0.000000
# 80646     73009          True         True 2021-08-09 11:52:00   0.000000
# 80647     73009          True         True 2021-08-09 13:14:00   0.000000
# 80648     73009          True         True 2021-08-09 11:44:00   0.000000
# 80649     73009          True         True 2021-08-09 11:46:00   7.284147
#
#        accuracy    altitude  verticalAccuracy   os          deviceModel  \
# 0            15  169.000000          0.000000  and      Xiaomi MI MAX 2
# 1            10   30.974026          4.000000  ios            iPhone8,1
# 2            21  103.000000          3.000000  and  motorola Moto G (5)
# 3             2   71.000000        108.000000  and     samsung SM-A530F
# 4            10   59.289700          4.000000  ios            iPhone7,2
# ...         ...         ...               ...  ...                  ...
# 80645      2000   50.126553         60.827324  ios           iPhone10,4
# 80646      2000   50.126553         60.827324  ios           iPhone10,4
# 80647      2000   50.126553         60.827324  ios           iPhone10,4
# 80648      2000   50.126553         60.827324  ios           iPhone10,4
# 80649      2000   50.126553         60.827324  ios           iPhone10,4
#
#                                        location
# 0      POINT(2.31323444843292 48.8488971590996)
# 1      POINT(2.31348294019699 48.8712033033371)
# 2      POINT(2.31104499101639 48.8806031346321)
# 3      POINT(2.31671500205994 48.8471108078957)
# 4      POINT(2.32746052742004 48.8833501338959)
# ...                                         ...
# 80645   POINT(2.32523882389069 48.858107984066)
# 80646  POINT(2.32524847984314 48.8581141829491)
# 80647    POINT(2.325235247612 48.8581080436707)
# 80648  POINT(2.32524710893631 48.8581057190895)
# 80649  POINT(2.32522505521774 48.8580371141434)
#
# [80650 rows x 11 columns]

# %%
vehicleid['trip_id'].nunique()
# Out:
# 303

# %%
uuid['pseudo_id'].nunique()
# Out:
# 6373

# %%
vehicleid['vehicle_id'].nunique()
# Out:
# 10

# %% [markdown]
# #### From initial analysis we found 10 VTCs had made 303 trips from 2021-09-14 23:59:44 to 2021-09-01 00:00:21
# #### 6373 devices are recorded

# %%
vehicleid['location'].value_counts()[:10]
# Out:
# POINT(2.3312365925 48.8732027065)    75
# POINT(2.3228238335 48.8677829045)    74
# POINT(2.3357133048 48.8725768275)    74
# POINT(2.3236888987 48.8689920975)    69
# POINT(2.3458345675 48.871012096)     69
# POINT(2.3396493514 48.8720362895)    63
# POINT(2.31672512395 48.864894949)    62
# POINT(2.335410532 48.872605277)      62
# POINT(2.3340264277 48.872804421)     61
# POINT(2.2959203062 48.8737574565)    60
# Name: location, dtype: int64

# %%
insee.head(2)
# Out:
#        IRIS   COM TYP_IRIS  MODIF_IRIS LAB_IRIS  P17_POP  P17_POP0002  \
# 0  10010000  1001        Z           0        5    776.0    29.145423
# 1  10020000  1002        Z           0        5    248.0    14.288066
#
#    P17_POP0305  P17_POP0610  P17_POP1117  ...  C17_F15P_CS4  C17_F15P_CS5  \
# 0    18.057932    57.197304    90.335473  ...     50.819279     85.780891
# 1    10.205761    14.288066    24.493827  ...     20.411523     25.514403
#
#    C17_F15P_CS6  C17_F15P_CS7  C17_F15P_CS8  P17_POP_FR  P17_POP_ETR  \
# 0     30.416743     71.592413     15.189774  767.876506     8.123494
# 1      0.000000     20.411523      0.000000  245.958848     2.041152
#
#    P17_POP_IMM  P17_PMEN  P17_PHORMEN
# 0    20.282806     776.0          0.0
# 1     3.061728     248.0          0.0
#
# [2 rows x 77 columns]

# %%
insee.columns
# Out:
# Index(['IRIS', 'COM', 'TYP_IRIS', 'MODIF_IRIS', 'LAB_IRIS', 'P17_POP',
#        'P17_POP0002', 'P17_POP0305', 'P17_POP0610', 'P17_POP1117',
#        'P17_POP1824', 'P17_POP2539', 'P17_POP4054', 'P17_POP5564',
#        'P17_POP6579', 'P17_POP80P', 'P17_POP0014', 'P17_POP1529',
#        'P17_POP3044', 'P17_POP4559', 'P17_POP6074', 'P17_POP75P',
#        'P17_POP0019', 'P17_POP2064', 'P17_POP65P', 'P17_POPH', 'P17_H0014',
#        'P17_H1529', 'P17_H3044', 'P17_H4559', 'P17_H6074', 'P17_H75P',
#        'P17_H0019', 'P17_H2064', 'P17_H65P', 'P17_POPF', 'P17_F0014',
#        'P17_F1529', 'P17_F3044', 'P17_F4559', 'P17_F6074', 'P17_F75P',
#        'P17_F0019', 'P17_F2064', 'P17_F65P', 'C17_POP15P', 'C17_POP15P_CS1',
#        'C17_POP15P_CS2', 'C17_POP15P_CS3', 'C17_POP15P_CS4', 'C17_POP15P_CS5',
#        'C17_POP15P_CS6', 'C17_POP15P_CS7', 'C17_POP15P_CS8', 'C17_H15P',
#        'C17_H15P_CS1', 'C17_H15P_CS2', 'C17_H15P_CS3', 'C17_H15P_CS4',
#        'C17_H15P_CS5', 'C17_H15P_CS6', 'C17_H15P_CS7', 'C17_H15P_CS8',
#        'C17_F15P', 'C17_F15P_CS1', 'C17_F15P_CS2', 'C17_F15P_CS3',
#        'C17_F15P_CS4', 'C17_F15P_CS5', 'C17_F15P_CS6', 'C17_F15P_CS7',
#        'C17_F15P_CS8', 'P17_POP_FR', 'P17_POP_ETR', 'P17_POP_IMM', 'P17_PMEN',
#        'P17_PHORMEN'],
#       dtype='object')

# %%
inseemeta.columns
# Out:
# Index(['COD_VAR', 'LIB_VAR', 'LIB_VAR_LONG', 'COD_MOD', 'LIB_MOD', 'TYPE_VAR',
#        'LONG_VAR'],
#       dtype='object')

# %%
# inseemeta

# %% [markdown]
# #### from insee data we extract the target audience data

# %%
dfpop = insee[['IRIS', 'COM', 'TYP_IRIS', 'MODIF_IRIS', 'LAB_IRIS', 'P17_POP65P']]

# %%
dfpop['P17_POP65P'].sum()
# Out:
# 12918050.761881253

# %% [markdown]
# ### We use INSEE GEO CODES TO GET COMMUNE CODES

# %%
com
# Out:
#       TYPECOM    COM   REG  DEP  CTCD  ARR  TNCC                    NCC  \
# 0         COM  01001  84.0   01   01D  012     5  ABERGEMENT CLEMENCIAT
# 1         COM  01002  84.0   01   01D  011     5    ABERGEMENT DE VAREY
# 2         COM  01004  84.0   01   01D  011     1      AMBERIEU EN BUGEY
# 3         COM  01005  84.0   01   01D  012     1    AMBERIEUX EN DOMBES
# 4         COM  01006  84.0   01   01D  011     1                AMBLEON
# ...       ...    ...   ...  ...   ...  ...   ...                    ...
# 37737     COM  97613   6.0  976  976D  NaN     0          M TSANGAMOUJI
# 37738     COM  97614   6.0  976  976D  NaN     1               OUANGANI
# 37739     COM  97615   6.0  976  976D  NaN     0               PAMANDZI
# 37740     COM  97616   6.0  976  976D  NaN     0                   SADA
# 37741     COM  97617   6.0  976  976D  NaN     0               TSINGONI
#
#                       NCCENR                  LIBELLE    CAN  COMPARENT
# 0      Abergement-Clémenciat  L'Abergement-Clémenciat   0108        NaN
# 1        Abergement-de-Varey    L'Abergement-de-Varey   0101        NaN
# 2          Ambérieu-en-Bugey        Ambérieu-en-Bugey   0101        NaN
# 3        Ambérieux-en-Dombes      Ambérieux-en-Dombes   0122        NaN
# 4                    Ambléon                  Ambléon   0104        NaN
# ...                      ...                      ...    ...        ...
# 37737          M'Tsangamouji            M'Tsangamouji  97613        NaN
# 37738               Ouangani                 Ouangani  97610        NaN
# 37739               Pamandzi                 Pamandzi  97611        NaN
# 37740                   Sada                     Sada  97612        NaN
# 37741               Tsingoni                 Tsingoni  97613        NaN
#
# [37742 rows x 12 columns]

# %%
com.loc[com['DEP'] == '75']
# Out:
#       TYPECOM    COM   REG DEP CTCD  ARR  TNCC                       NCC  \
# 31658     COM  75056  11.0  75  75C  751     0                     PARIS
# 31659     ARM  75101  11.0  75  75C  751     0  PARIS 1ER ARRONDISSEMENT
# 31660     ARM  75102  11.0  75  75C  751     0   PARIS 2E ARRONDISSEMENT
# 31661     ARM  75103  11.0  75  75C  751     0   PARIS 3E ARRONDISSEMENT
# 31662     ARM  75104  11.0  75  75C  751     0   PARIS 4E ARRONDISSEMENT
# 31663     ARM  75105  11.0  75  75C  751     0   PARIS 5E ARRONDISSEMENT
# 31664     ARM  75106  11.0  75  75C  751     0   PARIS 6E ARRONDISSEMENT
# 31665     ARM  75107  11.0  75  75C  751     0   PARIS 7E ARRONDISSEMENT
# 31666     ARM  75108  11.0  75  75C  751     0   PARIS 8E ARRONDISSEMENT
# 31667     ARM  75109  11.0  75  75C  751     0   PARIS 9E ARRONDISSEMENT
# 31668     ARM  75110  11.0  75  75C  751     0  PARIS 10E ARRONDISSEMENT
# 31669     ARM  75111  11.0  75  75C  751     0  PARIS 11E ARRONDISSEMENT
# 31670     ARM  75112  11.0  75  75C  751     0  PARIS 12E ARRONDISSEMENT
# 31671     ARM  75113  11.0  75  75C  751     0  PARIS 13E ARRONDISSEMENT
# 31672     ARM  75114  11.0  75  75C  751     0  PARIS 14E ARRONDISSEMENT
# 31673     ARM  75115  11.0  75  75C  751     0  PARIS 15E ARRONDISSEMENT
# 31674     ARM  75116  11.0  75  75C  751     0  PARIS 16E ARRONDISSEMENT
# 31675     ARM  75117  11.0  75  75C  751     0  PARIS 17E ARRONDISSEMENT
# 31676     ARM  75118  11.0  75  75C  751     0  PARIS 18E ARRONDISSEMENT
# 31677     ARM  75119  11.0  75  75C  751     0  PARIS 19E ARRONDISSEMENT
# 31678     ARM  75120  11.0  75  75C  751     0  PARIS 20E ARRONDISSEMENT
#
#                          NCCENR                   LIBELLE  CAN  COMPARENT
# 31658                     Paris                     Paris  NaN        NaN
# 31659  Paris 1er Arrondissement  Paris 1er Arrondissement  NaN    75056.0
# 31660   Paris 2e Arrondissement   Paris 2e Arrondissement  NaN    75056.0
# 31661   Paris 3e Arrondissement   Paris 3e Arrondissement  NaN    75056.0
# 31662   Paris 4e Arrondissement   Paris 4e Arrondissement  NaN    75056.0
# 31663   Paris 5e Arrondissement   Paris 5e Arrondissement  NaN    75056.0
# 31664   Paris 6e Arrondissement   Paris 6e Arrondissement  NaN    75056.0
# 31665   Paris 7e Arrondissement   Paris 7e Arrondissement  NaN    75056.0
# 31666   Paris 8e Arrondissement   Paris 8e Arrondissement  NaN    75056.0
# 31667   Paris 9e Arrondissement   Paris 9e Arrondissement  NaN    75056.0
# 31668  Paris 10e Arrondissement  Paris 10e Arrondissement  NaN    75056.0
# 31669  Paris 11e Arrondissement  Paris 11e Arrondissement  NaN    75056.0
# 31670  Paris 12e Arrondissement  Paris 12e Arrondissement  NaN    75056.0
# 31671  Paris 13e Arrondissement  Paris 13e Arrondissement  NaN    75056.0
# 31672  Paris 14e Arrondissement  Paris 14e Arrondissement  NaN    75056.0
# 31673  Paris 15e Arrondissement  Paris 15e Arrondissement  NaN    75056.0
# 31674  Paris 16e Arrondissement  Paris 16e Arrondissement  NaN    75056.0
# 31675  Paris 17e Arrondissement  Paris 17e Arrondissement  NaN    75056.0
# 31676  Paris 18e Arrondissement  Paris 18e Arrondissement  NaN    75056.0
# 31677  Paris 19e Arrondissement  Paris 19e Arrondissement  NaN    75056.0
# 31678  Paris 20e Arrondissement  Paris 20e Arrondissement  NaN    75056.0

# %% [markdown]
# ### Based on Vechile location data, we found out that most of its trips were in 48.87320 2.3312365 latitutes and langitutde which falls between  ARRONDISSEMENTS mostly surrounding 1ST.
#
# #### Hypothesis
# #### we select only parts were VTCs travelled and the population of target audience
# #### we narrowed it to 7 ARRONDISSEMENTS, 7th, 6th, 1th, 2th, 3th, 8th, 10th

# %%
communecodes = [75107, 75106, 75108, 75101, 75102, 75103, 75110]

# %%
dftarget = dfpop.loc[dfpop['COM'].isin(communecodes)]

# %%
dftarget['P17_POP65P'].sum()
# Out:
# 47700.57127948023

# %% [markdown]
# # KPI 1
# ## - The size of the target audience in the study area.
# ### 47700 Target Audience over 65 SPECIFIC THE SELECTED ARRONDISSEMENTS (Based on VTCs trip LOCATIONS)
# ### 12918050 Target Audience over 65 (FRANCE)

# %% [markdown]
# #### Differnt format of dates found. lets chnage both datsets date into a new format for analysis

# %%
uuid['date_uuid_new'] = uuid['date_uuid'].apply(lambda x: pd.Timestamp(x).strftime('%Y-%B-%d %I:%M %p'))

# %%
uuid
# Out:
#       pseudo_id  consentMedia  consentData           date_uuid      speed  \
# 0         0eb25          True         True 2021-09-14 13:58:00   0.000000
# 1         C3473          True         True 2021-09-09 18:27:00   0.000000
# 2         49cef          True         True 2021-09-14 12:50:00  13.046592
# 3         93e8c          True        False 2021-09-14 18:21:00  10.886680
# 4         56D83          True         True 2021-11-09 16:05:00   3.578376
# ...         ...           ...          ...                 ...        ...
# 80645     73009          True         True 2021-08-09 12:39:00   0.000000
# 80646     73009          True         True 2021-08-09 11:52:00   0.000000
# 80647     73009          True         True 2021-08-09 13:14:00   0.000000
# 80648     73009          True         True 2021-08-09 11:44:00   0.000000
# 80649     73009          True         True 2021-08-09 11:46:00   7.284147
#
#        accuracy    altitude  verticalAccuracy   os          deviceModel  \
# 0            15  169.000000          0.000000  and      Xiaomi MI MAX 2
# 1            10   30.974026          4.000000  ios            iPhone8,1
# 2            21  103.000000          3.000000  and  motorola Moto G (5)
# 3             2   71.000000        108.000000  and     samsung SM-A530F
# 4            10   59.289700          4.000000  ios            iPhone7,2
# ...         ...         ...               ...  ...                  ...
# 80645      2000   50.126553         60.827324  ios           iPhone10,4
# 80646      2000   50.126553         60.827324  ios           iPhone10,4
# 80647      2000   50.126553         60.827324  ios           iPhone10,4
# 80648      2000   50.126553         60.827324  ios           iPhone10,4
# 80649      2000   50.126553         60.827324  ios           iPhone10,4
#
#                                        location               date_uuid_new
# 0      POINT(2.31323444843292 48.8488971590996)  2021-September-14 01:58 PM
# 1      POINT(2.31348294019699 48.8712033033371)  2021-September-09 06:27 PM
# 2      POINT(2.31104499101639 48.8806031346321)  2021-September-14 12:50 PM
# 3      POINT(2.31671500205994 48.8471108078957)  2021-September-14 06:21 PM
# 4      POINT(2.32746052742004 48.8833501338959)   2021-November-09 04:05 PM
# ...                                         ...                         ...
# 80645   POINT(2.32523882389069 48.858107984066)     2021-August-09 12:39 PM
# 80646  POINT(2.32524847984314 48.8581141829491)     2021-August-09 11:52 AM
# 80647    POINT(2.325235247612 48.8581080436707)     2021-August-09 01:14 PM
# 80648  POINT(2.32524710893631 48.8581057190895)     2021-August-09 11:44 AM
# 80649  POINT(2.32522505521774 48.8580371141434)     2021-August-09 11:46 AM
#
# [80650 rows x 12 columns]

# %%
# vehicleid

# %%
vehicleid['date_vtc_new'] = vehicleid['date_vtc'].apply(lambda x: pd.Timestamp(x).strftime('%Y-%B-%d %I:%M %p'))

# %%
vehicleid
# Out:
#        vehicle_id                               trip_id            date_vtc  \
# 0             654  d2d6bfd5-83ae-4bd6-bb9d-d785316b0fec 2021-09-07 02:16:33
# 1             654  c3ab20fd-1e88-4a33-9017-80dcb661f3ed 2021-09-06 22:51:37
# 2             654  e93b5c42-db55-4f17-817d-77b0951facf1 2021-09-14 18:01:34
# 3             654  9a05e361-0930-4811-aca7-379628d75c1b 2021-09-03 02:02:34
# 4             654  21f577a1-11b4-489c-b31b-ff0fa211320f 2021-09-06 17:50:14
# ...           ...                                   ...                 ...
# 41995       59518  ff461cde-9f0e-49a4-9cbe-f53f6e5fa60b 2021-09-03 21:08:49
# 41996       59518  ff461cde-9f0e-49a4-9cbe-f53f6e5fa60b 2021-09-04 00:06:17
# 41997       59518  ff461cde-9f0e-49a4-9cbe-f53f6e5fa60b 2021-09-04 00:52:34
# 41998       59518  ff461cde-9f0e-49a4-9cbe-f53f6e5fa60b 2021-09-04 01:01:30
# 41999       59518  ff461cde-9f0e-49a4-9cbe-f53f6e5fa60b 2021-09-04 01:40:07
#
#                                  location                date_vtc_new
# 0       POINT(2.31166449265 48.873145809)  2021-September-07 02:16 AM
# 1       POINT(2.3432826252 48.8793899515)  2021-September-06 10:51 PM
# 2      POINT(2.32059629065 48.8656062835)  2021-September-14 06:01 PM
# 3       POINT(2.30513325045 48.874724698)  2021-September-03 02:02 AM
# 4        POINT(2.3072959134 48.874127286)  2021-September-06 05:50 PM
# ...                                   ...                         ...
# 41995    POINT(2.3235375123 48.869646472)  2021-September-03 09:08 PM
# 41996   POINT(2.3218290086 48.8660899855)  2021-September-04 12:06 AM
# 41997   POINT(2.31495174035 48.855575531)  2021-September-04 12:52 AM
# 41998   POINT(2.3225859406 48.8734018485)  2021-September-04 01:01 AM
# 41999    POINT(2.3468510191 48.883030823)  2021-September-04 01:40 AM
#
# [42000 rows x 5 columns]

# %%
vehicleid.sort_values(by='date_vtc_new', ascending=False)
# Out:
#        vehicle_id                               trip_id            date_vtc  \
# 24740         654  4d4d17a6-8065-4129-bd79-d67932ec0e74 2021-09-14 00:59:26
# 24614         654  4d4d17a6-8065-4129-bd79-d67932ec0e74 2021-09-14 00:59:55
# 24765         654  4d4d17a6-8065-4129-bd79-d67932ec0e74 2021-09-14 00:59:43
# 24701         654  4d4d17a6-8065-4129-bd79-d67932ec0e74 2021-09-14 00:59:08
# 24677         654  4d4d17a6-8065-4129-bd79-d67932ec0e74 2021-09-14 00:59:30
# ...           ...                                   ...                 ...
# 29663       49099  883d3ac3-e877-4ac4-acd9-4f6f330b8a9f 2021-09-01 01:00:59
# 29683       49099  883d3ac3-e877-4ac4-acd9-4f6f330b8a9f 2021-09-01 01:00:21
# 8242        81779  2305c57b-ce59-494d-8ff8-c46681a4b47a 2021-09-01 01:00:08
# 29598       49099  883d3ac3-e877-4ac4-acd9-4f6f330b8a9f 2021-09-01 01:00:16
# 29590       49099  883d3ac3-e877-4ac4-acd9-4f6f330b8a9f 2021-09-01 01:00:24
#
#                                    location                date_vtc_new
# 24740      POINT(2.3085286313 48.875037625)  2021-September-14 12:59 AM
# 24614     POINT(2.30571716945 48.874966505)  2021-September-14 12:59 AM
# 24765  POINT(2.30722382463333 48.874980729)  2021-September-14 12:59 AM
# 24701      POINT(2.312399798 48.8751940875)  2021-September-14 12:59 AM
# 24677    POINT(2.30885303075 48.8750518485)  2021-September-14 12:59 AM
# ...                                     ...                         ...
# 29663     POINT(2.33681626295 48.872406132)  2021-September-01 01:00 AM
# 29683      POINT(2.3388275395 48.873558315)  2021-September-01 01:00 AM
# 8242      POINT(2.30645247485 48.851235363)  2021-September-01 01:00 AM
# 29598     POINT(2.33815711395 48.872249661)  2021-September-01 01:00 AM
# 29590      POINT(2.338330127 48.8723919075)  2021-September-01 01:00 AM
#
# [42000 rows x 5 columns]

# %%
uuid.sort_values(by='date_uuid_new', ascending=False)
# Out:
#       pseudo_id  consentMedia  consentData           date_uuid      speed  \
# 11863     49cef          True         True 2021-09-14 12:59:00  10.127128
# 43465     2A993          True         True 2021-09-14 12:59:00  -1.000000
# 55236     596A0          True         True 2021-09-14 12:59:00  -1.000000
# 78138     3b6ae          True         True 2021-09-14 12:59:00  18.333261
# 72353     f92ae          True         True 2021-09-14 12:59:00   2.660160
# ...         ...           ...          ...                 ...        ...
# 9351      25D3B          True         True 2021-04-09 13:05:00  14.403890
# 20431     EB0A8          True         True 2021-04-09 01:05:00   6.948732
# 31891     1A023          True         True 2021-04-09 01:04:00   1.310769
# 76340     af7ba          True         True 2021-04-09 13:03:00   7.317928
# 76726     af7ba          True         True 2021-04-09 13:00:00   0.000000
#
#        accuracy    altitude  verticalAccuracy   os          deviceModel  \
# 11863        24  107.000000          3.000000  and  motorola Moto G (5)
# 43465        65    0.000000          0.000000  ios            iPhone9,3
# 55236        38    0.000000          0.000000  ios            iPhone6,2
# 78138        73   91.000000          3.000000  and         Xiaomi Mi 9T
# 72353        11   86.000000          3.000000  and     samsung SM-G950F
# ...         ...         ...               ...  ...                  ...
# 9351         17   39.041714          4.000000  ios           iPhone13,4
# 20431      2190   50.765698          5.042618  ios           iPhone13,4
# 31891        48   25.392495          3.000000  ios            iPhone9,3
# 76340       500   83.000000          3.000000  and       HUAWEI COL-L29
# 76726        73   83.000000          3.000000  and       HUAWEI COL-L29
#
#                                        location               date_uuid_new
# 11863  POINT(2.33360707759857 48.8833734989166)  2021-September-14 12:59 PM
# 43465  POINT(2.31876122951508 48.8756526112556)  2021-September-14 12:59 PM
# 55236  POINT(2.31066530942917 48.8712732791901)  2021-September-14 12:59 PM
# 78138  POINT(2.30270832777023 48.8770411610603)  2021-September-14 12:59 PM
# 72353  POINT(2.30290728807449 48.8691599965096)  2021-September-14 12:59 PM
# ...                                         ...                         ...
# 9351   POINT(2.30138051509857 48.8681710958481)      2021-April-09 01:05 PM
# 20431   POINT(2.3349152803421 48.8800823092461)      2021-April-09 01:05 AM
# 31891  POINT(2.30999904870987 48.8691719770432)      2021-April-09 01:04 AM
# 76340   POINT(2.3189445734024 48.8770438432693)      2021-April-09 01:03 PM
# 76726  POINT(2.32426244020462 48.8764102458954)      2021-April-09 01:00 PM
#
# [80650 rows x 12 columns]

# %%
vehicleid['location'].value_counts()
# Out:
# POINT(2.3312365925 48.8732027065)     75
# POINT(2.3228238335 48.8677829045)     74
# POINT(2.3357133048 48.8725768275)     74
# POINT(2.3236888987 48.8689920975)     69
# POINT(2.3458345675 48.871012096)      69
#                                       ..
# POINT(2.3155789126 48.8780103335)      1
# POINT(2.32481348345 48.8753647735)     1
# POINT(2.3032084804 48.852786483)       1
# POINT(2.2938441498 48.8556751375)      1
# POINT(2.3019757625 48.86974605)        1
# Name: location, Length: 17376, dtype: int64

# %%
uuid['location'].value_counts()
# Out:
# POINT(2.34895515441895 48.8797829151154)    118
# POINT(2.32214039564133 48.8710516095161)     54
# POINT(2.32213819026947 48.871049284935)      49
# POINT(2.322141289711 48.8710499405861)       45
# POINT(2.32214057445526 48.8710505366325)     45
#                                            ...
# POINT(2.29568886756897 48.8746188282967)      1
# POINT(2.3248410820961 48.8829468488693)       1
# POINT(2.32185649871826 48.8753682971001)      1
# POINT(2.3158073425293 48.8730158209801)       1
# POINT(2.30932664871216 48.8751915097237)      1
# Name: location, Length: 70731, dtype: int64

# %%
res = pd.merge(uuid,vehicleid,on='location')
res
# Out:
# Empty DataFrame
# Columns: [pseudo_id, consentMedia, consentData, date_uuid, speed, accuracy, altitude, verticalAccuracy, os, deviceModel, location, date_uuid_new, vehicle_id, trip_id, date_vtc, date_vtc_new]
# Index: []

# %% [markdown]
# ###  Inner join on location returns empty dataframe, No common location data points were found

# %%
vehicleid.columns
# Out:
# Index(['vehicle_id', 'trip_id', 'date_vtc', 'location', 'date_vtc_new'], dtype='object')

# %%
uuid.columns
# Out:
# Index(['pseudo_id', 'consentMedia', 'consentData', 'date_uuid', 'speed',
#        'accuracy', 'altitude', 'verticalAccuracy', 'os', 'deviceModel',
#        'location', 'date_uuid_new'],
#       dtype='object')

# %%
vehicleid = vehicleid.rename(columns={'date_vtc_new': 'date'})
uuid = uuid.rename(columns={'date_uuid_new': 'date'})

# %%
res1 = pd.merge(uuid,vehicleid,on='date')
res1
# Out:
#       pseudo_id  consentMedia  consentData           date_uuid      speed  \
# 0         DE407          True         True 2021-09-09 16:26:00  26.055253
# 1         DE407          True         True 2021-09-09 16:26:00  26.055253
# 2         DE407          True         True 2021-09-09 16:26:00  26.055253
# 3         DE407          True         True 2021-09-09 16:26:00  26.055253
# 4         12CE0          True         True 2021-09-09 16:26:00   3.597444
# ...         ...           ...          ...                 ...        ...
# 34415     80f91          True         True 2021-09-09 02:18:00  31.781294
# 34416     80f91          True         True 2021-09-09 02:18:00  31.781294
# 34417     80f91          True         True 2021-09-09 02:18:00  31.781294
# 34418     80f91          True         True 2021-09-09 02:18:00  31.781294
# 34419     80f91          True         True 2021-09-09 02:18:00  31.781294
#
#        accuracy   altitude  verticalAccuracy   os     deviceModel  \
# 0             7  33.761055          2.877530  ios      iPhone12,1
# 1             7  33.761055          2.877530  ios      iPhone12,1
# 2             7  33.761055          2.877530  ios      iPhone12,1
# 3             7  33.761055          2.877530  ios      iPhone12,1
# 4            65  30.799059         16.136425  ios      iPhone12,1
# ...         ...        ...               ...  ...             ...
# 34415         9  95.000000          3.000000  and  HUAWEI VOG-L29
# 34416         9  95.000000          3.000000  and  HUAWEI VOG-L29
# 34417         9  95.000000          3.000000  and  HUAWEI VOG-L29
# 34418         9  95.000000          3.000000  and  HUAWEI VOG-L29
# 34419         9  95.000000          3.000000  and  HUAWEI VOG-L29
#
#                                      location_x                        date  \
# 0      POINT(2.31601095199585 48.8648746609688)  2021-September-09 04:26 PM
# 1      POINT(2.31601095199585 48.8648746609688)  2021-September-09 04:26 PM
# 2      POINT(2.31601095199585 48.8648746609688)  2021-September-09 04:26 PM
# 3      POINT(2.31601095199585 48.8648746609688)  2021-September-09 04:26 PM
# 4      POINT(2.32815647125244 48.8736560940742)  2021-September-09 04:26 PM
# ...                                         ...                         ...
# 34415  POINT(2.33188313245773 48.8763880133629)  2021-September-09 02:18 AM
# 34416  POINT(2.33188313245773 48.8763880133629)  2021-September-09 02:18 AM
# 34417  POINT(2.33188313245773 48.8763880133629)  2021-September-09 02:18 AM
# 34418  POINT(2.33188313245773 48.8763880133629)  2021-September-09 02:18 AM
# 34419  POINT(2.33188313245773 48.8763880133629)  2021-September-09 02:18 AM
#
#        vehicle_id                               trip_id            date_vtc  \
# 0           97510  3616c0fc-d50f-4439-9284-1d8ad64f736c 2021-09-09 16:26:12
# 1           97510  3616c0fc-d50f-4439-9284-1d8ad64f736c 2021-09-09 16:26:02
# 2           97510  3616c0fc-d50f-4439-9284-1d8ad64f736c 2021-09-09 16:26:12
# 3           97510  3616c0fc-d50f-4439-9284-1d8ad64f736c 2021-09-09 16:26:02
# 4           97510  3616c0fc-d50f-4439-9284-1d8ad64f736c 2021-09-09 16:26:12
# ...           ...                                   ...                 ...
# 34415       87016  b4fdb132-996a-4b00-b3b1-7154122539dc 2021-09-09 02:18:23
# 34416       87016  b4fdb132-996a-4b00-b3b1-7154122539dc 2021-09-09 02:18:15
# 34417       87016  b4fdb132-996a-4b00-b3b1-7154122539dc 2021-09-09 02:18:42
# 34418       87016  b4fdb132-996a-4b00-b3b1-7154122539dc 2021-09-09 02:18:39
# 34419       87016  b4fdb132-996a-4b00-b3b1-7154122539dc 2021-09-09 02:18:05
#
#                                location_y
# 0       POINT(2.3221966613 48.8715099705)
# 1      POINT(2.32245618085 48.8711401215)
# 2       POINT(2.3221966613 48.8715099705)
# 3      POINT(2.32245618085 48.8711401215)
# 4       POINT(2.3221966613 48.8715099705)
# ...                                   ...
# 34415   POINT(2.3134378762 48.8630312045)
# 34416   POINT(2.31328648985 48.861508857)
# 34417    POINT(2.3136108893 48.864268966)
# 34418   POINT(2.31356763605 48.863927517)
# 34419  POINT(2.31335136975 48.8621491005)
#
# [34420 rows x 16 columns]

# %%
res1['pseudo_id'].nunique()
# Out:
# 1579

# %% [markdown]
# The OPS can be  calculated as follows: The net reach is the number of persons reached once. The gross reach is the number of persons reached regardless of the number of times the ad has been shown. The OTS value is obtained by dividing the gross reach by the net reach.
# REFERENCE: https://en.ryte.com/wiki/Opportunity_To_See

# %%
uuid['pseudo_id'].nunique()
# Out:
# 6373

# %%
OPS = res1['pseudo_id'].nunique()/uuid['pseudo_id'].nunique()
OPS
# Out:
# 0.24776400439353521

# %% [markdown]
# ## KPI 2
# ### The number of Opportunities To See (OTV) generated by the campaign
# #### UUID VTC datasets have location and date common columns, location has no common values in two datasets.
#
# #### Hypothesis - if the timestamp matches, that means the smartphone user has in contact with the VTC, unique values of the merged dataset gives the no. people has seen the ad (without considering the repetition).
# #### unique uuids in UUID DATSET gives the total number if audience, using these two values,OTV is calculated.

# %%
vehicleid['trip_id'].value_counts()
# Out:
# a8656b6d-0d63-42f1-9dcd-88617f9bba11    751
# de78be08-06af-4675-b4d9-ef26644ae8c8    695
# 06ce7f4e-3143-4348-ad1c-4afbe05ddb82    618
# ed86364d-7063-4512-924d-d258926ea69f    590
# cc14dc68-7e27-491b-aafe-fb9e2c55d0f9    581
#                                        ...
# 992221fb-2f41-492d-909e-3413eff3014c      3
# 56de968f-55e7-4b48-aff6-9c80fba591bc      2
# 6cebb40a-ce14-4626-a30c-cf3ad46983b7      1
# 106d1ff3-fae7-4f57-8cb4-179a61776032      1
# 183ae901-f0dd-4021-bb81-7685e7a721dd      1
# Name: trip_id, Length: 303, dtype: int64

# %%
vehicleid.loc[vehicleid['trip_id'] == 'a8656b6d-0d63-42f1-9dcd-88617f9bba11']
# Out:
#        vehicle_id                               trip_id            date_vtc  \
# 31789       81779  a8656b6d-0d63-42f1-9dcd-88617f9bba11 2021-09-10 05:08:09
# 31790       81779  a8656b6d-0d63-42f1-9dcd-88617f9bba11 2021-09-10 05:51:08
# 31791       81779  a8656b6d-0d63-42f1-9dcd-88617f9bba11 2021-09-10 05:08:15
# 31792       81779  a8656b6d-0d63-42f1-9dcd-88617f9bba11 2021-09-10 03:29:57
# 31793       81779  a8656b6d-0d63-42f1-9dcd-88617f9bba11 2021-09-10 03:23:33
# ...           ...                                   ...                 ...
# 32535       81779  a8656b6d-0d63-42f1-9dcd-88617f9bba11 2021-09-10 03:56:48
# 32536       81779  a8656b6d-0d63-42f1-9dcd-88617f9bba11 2021-09-10 03:18:36
# 32537       81779  a8656b6d-0d63-42f1-9dcd-88617f9bba11 2021-09-10 06:43:50
# 32538       81779  a8656b6d-0d63-42f1-9dcd-88617f9bba11 2021-09-10 05:13:30
# 32539       81779  a8656b6d-0d63-42f1-9dcd-88617f9bba11 2021-09-10 06:48:17
#
#                                  location                        date
# 31789  POINT(2.31957983905 48.8634153405)  2021-September-10 05:08 AM
# 31790     POINT(2.3430663589 48.87298934)  2021-September-10 05:51 AM
# 31791   POINT(2.3194717059 48.8632872955)  2021-September-10 05:08 AM
# 31792    POINT(2.3037275195 48.870997871)  2021-September-10 03:29 AM
# 31793   POINT(2.30965321605 48.857112288)  2021-September-10 03:23 AM
# ...                                   ...                         ...
# 32535    POINT(2.300721418 48.8595027035)  2021-September-10 03:56 AM
# 32536   POINT(2.3120537719 48.8479052745)  2021-September-10 03:18 AM
# 32537   POINT(2.3144110746 48.8507372875)  2021-September-10 06:43 AM
# 32538    POINT(2.31436782135 48.85077998)  2021-September-10 05:13 AM
# 32539  POINT(2.31438944795 48.8628747035)  2021-September-10 06:48 AM
#
# [751 rows x 5 columns]

# %%
rept= pd.DataFrame(vehicleid['location'].value_counts())
rept
# Out:
#                                     location
# POINT(2.3312365925 48.8732027065)         75
# POINT(2.3228238335 48.8677829045)         74
# POINT(2.3357133048 48.8725768275)         74
# POINT(2.3236888987 48.8689920975)         69
# POINT(2.3458345675 48.871012096)          69
# ...                                      ...
# POINT(2.3155789126 48.8780103335)          1
# POINT(2.32481348345 48.8753647735)         1
# POINT(2.3032084804 48.852786483)           1
# POINT(2.2938441498 48.8556751375)          1
# POINT(2.3019757625 48.86974605)            1
#
# [17376 rows x 1 columns]

# %%
rept[rept['location'] > 1]
# Out:
#                                     location
# POINT(2.3312365925 48.8732027065)         75
# POINT(2.3228238335 48.8677829045)         74
# POINT(2.3357133048 48.8725768275)         74
# POINT(2.3236888987 48.8689920975)         69
# POINT(2.3458345675 48.871012096)          69
# ...                                      ...
# POINT(2.3199691184 48.8734160725)          2
# POINT(2.33225304405 48.8769862625)         2
# POINT(2.32920368925 48.8797455175)         2
# POINT(2.33486986625 48.875208311)          2
# POINT(2.30868001775 48.864553505)          2
#
# [4966 rows x 1 columns]

# %%
rept[rept['location'] > 1].shape[0]
# Out:
# 4966

# %%
rept.shape[0]
# Out:
# 17376

# %%
avg = (rept[rept['location'] > 1].shape[0] / rept.shape[0]) * 100

# %%
avg
# Out:
# 28.57965009208103

# %% [markdown]
# ## KPI3
# ### The average repetition of the campaign  28.3 percent
#
# #### Hypothesis, Repeated ads are the ads thats happened in the same location more than once, so my taking the unique ads that happened more than once and dividing it with total number of ads gives the average repetition of campaign

# %%
dfpop1 = insee[['IRIS', 'COM', 'TYP_IRIS', 'MODIF_IRIS', 'LAB_IRIS', 'P17_POP']]

# %%
dfaudienc = dfpop1.loc[dfpop['COM'].isin(communecodes)]

# %%
dfaudienc['P17_POP'].sum()
# Out:
# 290928.0

# %% [markdown]
# ## KPI4
# ### - The audience of the campaign
#
# #### based on selected area the audience of campaign is 290928

# %% [markdown]
# ## KPI5
# ### - The advertising coverage
# #### we select only parts were VTCs travelled to get the advertising coverage
# #### we narrowed it to 7 ARRONDISSEMENTS of PARIS 7th, 6th, 1th, 2th, 3th, 8th, 10th
